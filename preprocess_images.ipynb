# %% [markdown]
# <a href="https://colab.research.google.com/github/ondraperny/BI-BAP-2020/blob/master/preprocess_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data preprocessor
# Modul for preprocessing images. \
# **Copy whole content of directory recursively (without changing the structure) and apply specified filters to copied images.**
#
#  Every method in class *ImageFilters* is applicable filters.
#
#  ### Instructions:
#  1) Specify "PATH_ORIGIN" path to an input directory \
#  2) Specify "PATH_DEST" path to output directory (inside will be created directory containing all processed images, named by the transformations that were made. \
#  3) Choose what filters you want to use
#   pass them as parameters to method copy_imgs_apply_filters in last cell.

# %% [markdown]
# ## Imports

# %%
from PIL import Image
from pathlib import Path
import numpy as np
import os
import IPython.display
import cv2

# %%
import sys
# check if code run on colab or local
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab.patches import cv2_imshow
  # Mount google drive
  from google.colab import drive
  drive.mount('/content/drive')

# %% [markdown]
# **PATH_ORIGIN**      is path to directory with input data \
# **PATH_DEST** is path to directory where copy of transformed data will be saved(file structure of transformed dir will remain same)\
# If we dont want to create copy, just transform data in-place, then set PATH_DEST = PATH_ORIGIN.

# %%
# example path
# PATH_ORIGIN= "/content/drive/My Drive/XR_ELBOW/"

# path on colab
PATH_ORIGIN= ""
PATH_DEST = ""


# Allow to show processed data during preproccesing - graphical output slowing
# a lot, so by default False
DEBUG_ON = False

# %% [markdown]
# ## Data manipulation class
# currently only class with all required methods

# %%
class DataManipulation():
  """Encapsulate functions that are neccesary for processing images
  and handling file structure
  
  Attributes
  ----------
  PATH_ORIGIN : str
    valid path to dir with input data
  PATH_DESTINATION : str
    path to dir with output data (path does not have to exist yet)

  Methods
  -------
  correct_dir_path(path)
    If path string does not end with '\', it adds it to the path
  change_path(old_path, destination_path, file_path)
    Change path of file from old dir to a new one
  generate_subdirs(in_path)
  generate_image_paths(dir_path)
  open_image(image_path, return_in_PIL_format = False)
  save_image(image_numpy_array, path_to_dir, image_name)
  show_images(*images)
  copy_imgs_apply_filters(self, max_images_per_dir, *filters)
    Loads images from from PATH_ORIGIN, pply every filter function to an images
    and save in same file structure
  check_file_exists(img)
  """

  def __init__(self, PATH_ORIGIN, PATH_DESTINATION):
    if not IN_COLAB:
      PATH_ORIGIN =      "G:"+PATH_ORIGIN[14:].replace('/', '\\\\')
      PATH_DESTINATION = "G:"+PATH_DESTINATION[14:].replace('/', '\\\\')
    self.PATH_ORIGIN = PATH_ORIGIN
    self.PATH_DESTINATION = PATH_DESTINATION

  def correct_dir_path(self, path):
    """check if string is correct path to directory - ends with slash
    if it doesn't, it adds it
    @return correct path"""
    if path[-1] != '/' and IN_COLAB:
      path = path + '/'
    elif path[-1] != '\\' and not IN_COLAB:
      path = path + '\\'
    return path

  def change_path(self, old_path, destination_path, file_path):
    """take file_path, trim old_path from it and add destination_path instead"""
    old_path = self.correct_dir_path(old_path)
    old_path_len = len(old_path)
    # cut off prefix(old_path) from file_path
    dir_path_from_current = str(file_path)[old_path_len:]
    destination_path = self.correct_dir_path(destination_path)
    return destination_path + dir_path_from_current

  @staticmethod
  def generate_subdirs(dir_path):
    """Return generator to all subdirectories of in_path"""
    for path in Path(dir_path).glob("**"):
      yield path

  @staticmethod
  def generate_image_paths(dir_path):
    """Generator with path to every png image in specified dir"""
    for image in Path(dir_path).glob("*.png"):
      yield image

  @staticmethod
  def open_image(image_path, return_in_PIL_format = False):
    """Open image, based on parameter return image type"""
    try:
      image_PIL = Image.open(image_path).convert('L')
      # image_PIL = Image.open(image_path).convert('RGB')
      if return_in_PIL_format:
        return image_PIL
      else:
        return np.array(image_PIL)
    except:
      print("Can't open image \"" + str(image_path) + "\"")

  def save_image(self, image_numpy_array, path_to_dir, image_name):
    """Save image to specified path, with specified name"""
    path_to_dir = self.correct_dir_path(path_to_dir)
    image = Image.fromarray(image_numpy_array)
    image.save(path_to_dir+image_name)

    print("Image " + image_name + " saved in " + path_to_dir)

  @staticmethod
  def show_images(*images):
    for img in images:
      IPython.display.display(Image.fromarray(img))

  def copy_imgs_apply_filters(self, max_images_per_dir, *filters):
    """Create directories in new path and copy all images in those directories, as well
    apply filter on image
    
    Parameters
    ----------
    max_images_per_dir : int
      maximum amount of processed images per directory, by default (= 0) process
      every image found
    """

    for directory in self.generate_subdirs(self.PATH_ORIGIN):
      # Create target directory & all intermediate directories if don't exists
      new_path = self.change_path(self.PATH_ORIGIN, self.PATH_DESTINATION, directory)
      # print(new_path)
      try:
        os.makedirs(new_path)    
        print("Directory created: " , new_path)
      except FileExistsError:
        print("Directory already exists: " , new_path)
      
      cnt = 0
      for image_path in self.generate_image_paths(directory):
        new_image_path = self.correct_dir_path(new_path) + Path(image_path).name
        if self.check_file_exists(new_image_path): # and not DEBUG_ON:
          print("File already exists: " + new_image_path)
        else:
          image = self.open_image(image_path)
          try:
            for filter in filters:
              image = filter(image)          
            self.save_image((image), new_path, Path(image_path).name)
          except ValueError as ve:
            print("File could not be processed: ", image_path)


        if max_images_per_dir == 0:
          continue
        elif cnt >= max_images_per_dir:
          break
        else:
          cnt = cnt + 1

    print("All images were processed.")

  @staticmethod
  def check_file_exists(path):
    return Path(path).is_file()

# %% [markdown]
# ## Support functions for processing images
# Encapsulated in class ImageProcessing

# %%
class ImageProcessing:
  """Encapsulate all image processing functions
  
  Methods
  -------
  rotate_img_if_needed(img)
  crop_rectangle(rect, src)
  revert_mask_if_needed(img_mask)
  erode(img)
  dilate(img)
  find_contour(ref_mask)
  draw_contour(image, contours)
  otsu_thresh_after_gauss(img)
  """

  @staticmethod
  def add_border(img, border_type=cv2.BORDER_CONSTANT, border_size=500):
    """Adds border to image, by default constant black color, with border width 100px""" 
    img_border = cv2.copyMakeBorder(
      img,
      top=border_size,
      bottom=border_size,
      left=border_size,
      right=border_size,
      borderType=border_type,
      value=[0, 0, 0]
      )
    return img_border

  @staticmethod
  def rotate_img_if_needed(img):
    """If width of image is bigger than his height, it is rotated to left by 90"""
    h, w = img.shape[0:2]
    if DEBUG_ON:
      print("Rotated image shape, height:", h, ",width:", w)
    if w > h:
      return cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
    return img

  @staticmethod
  def crop_rectangle(rect, src):
    """Cut rotated rectangle from src image"""
    # Get center, size, and angle from rect
    center, size, theta = rect
    # Convert to int 
    center, size = tuple(map(int, center)), tuple(map(int, size))
    # Get rotation matrix for rectangle
    M = cv2.getRotationMatrix2D( center, theta, 1)
    # Perform rotation on src image
    dst = cv2.warpAffine(src, M, src.shape[:2])
    if DEBUG_ON:
      print("After warping:")
      cv2_imshow(dst)
    out = cv2.getRectSubPix(dst, size, center)
    return out
    
  @staticmethod
  def revert_mask_if_needed(img_mask):
    h, w = img_mask.shape[0:2]
    bottom_right = img_mask[h-1, w-1]
    bottom_left = img_mask[0, w-1]
    upper_left = img_mask[0, 0]
    upper_right = img_mask[h-1, 0]
    if int(bottom_right) + int(bottom_left) + int(upper_left) + int(upper_right) > 255:
      img_mask = 255 - img_mask
    if DEBUG_ON:
      # print(h, w)
      print("Colors in corners(0 - black) bottom_right, bottom_left, upper_left, upper_right:", h-1, w-1, 0, w-1, 0, 0, h-1, 0)
      print(bottom_right, bottom_left, upper_left, upper_right)
      print(int(bottom_right) + int(bottom_left) + int(upper_left) + int(upper_right))
    return img_mask

  # during erosion white part is reduced
  @staticmethod
  def erode(img):
    kernel = np.ones((10,10),np.uint8)
    erosion = cv2.erode(img,kernel,iterations = 3)
    return erosion

  # during dilation white part is increased (background is black)
  @staticmethod
  def dilate(img):
    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(img,kernel,iterations = 2)
    return dilation

  @staticmethod
  def find_contour(ref_mask):
    """find all contours of image"""
    _, contours, hierarchy = cv2.findContours(ref_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    if DEBUG_ON:
      print(f'Found {len(contours)} contours.')
    return contours

  @staticmethod
  def draw_contour(image, contours):
    """draw contours onto an image"""
    contour_drawn = cv2.drawContours(image.copy(), contours, -1, color=(255, 0, 0 ), thickness=10)
    if DEBUG_ON:
      cv2_imshow(contour_drawn)

  # ref: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_thresholding/py_thresholding.html
  @staticmethod
  def otsu_thresh_after_gauss(img):
    """Otsu's thresholding after Gaussian filtering"""
    blur = cv2.GaussianBlur(img,(5,5),0)
    _, th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    return th3

# %% [markdown]
# ## Specific filters that can be used on data
# Encapsulated in class ImageFilters

# %%
class ImageFilters:
  """Encapsulate all image filter functions
  
  Methods
  -------
  smoother(img)
  histogram_equalization(img)
    apply histogram equalization on image
  clahe(img)
    apply clahe on image
  crop_ROI_rect(img)
    find region of interest (bone in x-rays) and cut the smallest rotated
    rectangle, image is rotated so bone is straight up (result of cropping rotatedRect)
  crop_ROI_square_224(img)
    find region of interest (bone in x-rays) and cut 244x244 pixels image
    from center of the region of interest
  resize_img_224(img)
    resize image to 224x244 px
  """

  @staticmethod
  def smoother(img):
    """smoother the image"""
    kernel = np.ones((5,5),np.float32)/25
    return cv2.filter2D(img,-1,kernel)

  @staticmethod
  def histogram_equalization(img):
    """Spread most frequent intensity values, creating better contrast image"""
    return cv2.equalizeHist(img)
  
  @staticmethod
  def clahe(img):
    """Contrast limited adaptive histogram equalization - works with adaptive
    areas with small contrast amplification"""
    clahe =  cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    return clahe.apply(img)

  @staticmethod
  def crop_ROI_rect(img):
    """TODO: perfect dilating picture and then properly cut ROI zones from
    pictures"""
    if DEBUG_ON:
      print("Original image:")
      cv2_imshow(img)

    img_mask = ImageProcessing.otsu_thresh_after_gauss(img)
    img_mask = ImageProcessing.erode(img_mask)
    img_mask = ImageProcessing.dilate(img_mask)
    img_mask = ImageProcessing.revert_mask_if_needed(img_mask)
    img_mask_border = ImageProcessing.add_border(img_mask)

    img = ImageProcessing.add_border(img, cv2.BORDER_DEFAULT)

    if DEBUG_ON:
      print("Original image with border:")
      cv2_imshow(img)
      print("Mask image with border:")
      cv2_imshow(img_mask_border)

    contours = ImageProcessing.find_contour(img_mask_border)
    cont = np.vstack(contours)
    hull = cv2.convexHull(cont)

    rect = cv2.minAreaRect(hull)

    if DEBUG_ON:
      print("Minimal area bounding rect:")
      box = cv2.boxPoints(rect)
      box = np.int0(box)
      tmp_img=numpy.array(img)
      cv2.drawContours(tmp_img, [box], 0, (0, 0, 255))
      cv2_imshow(tmp_img)

    
    img = ImageProcessing.crop_rectangle(rect, img)
    if DEBUG_ON:
      print("Cropped final image(before possible rotation):")
      cv2_imshow(img)
    img = ImageProcessing.rotate_img_if_needed(img)
    
    if DEBUG_ON:
      print("Cropped final image(and mby rotated):")
      cv2_imshow(img)
      print("------------------------------------------------------------------------------")
      
    return img 

  @staticmethod
  def crop_ROI_square_224(img):
    """TODO: perfect dilating picture and then properly cut ROI zones from
    pictures"""
    if DEBUG_ON:
      cv2_imshow(img)

    img_mask = ImageProcessing.otsu_thresh_after_gauss(img)
    img_mask = ImageProcessing.erode(img_mask)
    img_mask = ImageProcessing.dilate(img_mask)
    img_mask = ImageProcessing.revert_mask_if_needed(img_mask)
    border = ImageProcessing.add_border(img_mask)

    if DEBUG_ON:
      cv2_imshow(border)

    img = ImageProcessing.add_border(img, cv2.BORDER_DEFAULT)

    # find contours and create convex hull object from them
    contours = ImageProcessing.find_contour(border)
    cont = np.vstack(contours)
    hull = cv2.convexHull(cont)

    # find moments of convex hull
    moments = cv2.moments(hull)
    X_coord = int(moments["m10"] / moments["m00"])
    Y_coord = int(moments["m01"] / moments["m00"])

    # maximal distance from center - resulting in 224x224 image
    max_dist = 112
    img = img[Y_coord-max_dist:Y_coord+max_dist,
              X_coord-max_dist:X_coord+max_dist]

    if DEBUG_ON:
      cv2.circle(img, (X_coord, Y_coord), 5, (255, 255, 255), -1) 
      print("x, y:", X_coord, Y_coord)
      cv2_imshow(img)
      print("------------------------------------------------------------------------------")

    return img

  @staticmethod
  def resize_img_224(img):
    return cv2.resize(img, (224, 224), interpolation = cv2.INTER_AREA)

# %%
## init required classes
preprocess = DataManipulation(PATH_ORIGIN, PATH_DEST)

# preprocess.copy_imgs_apply_filters(0, ImageFilters.histogram_equalization)
# preprocess.copy_imgs_apply_filters(0)
preprocess.copy_imgs_apply_filters(0, ImageFilters.clahe, ImageFilters.crop_ROI_rect)
# Out:
# Streaming output truncated to the last 5000 lines.
# Image 403.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 404.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 405.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 406.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 407.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 408.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 409.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 410.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 411.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 412.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 413.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 414.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 415.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 416.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 417.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 418.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 419.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 420.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 421.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 422.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 423.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 424.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 425.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 426.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 427.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 428.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 429.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 430.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 431.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 432.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 433.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 434.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 435.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 436.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 437.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 438.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 439.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 440.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 441.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 442.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 443.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 444.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 445.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 446.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 447.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 448.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 449.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 450.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 451.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 452.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 453.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 454.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 455.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 456.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 457.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 458.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 459.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 460.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 461.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 462.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 463.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 464.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 465.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 466.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 467.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 468.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 469.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 470.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 471.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 472.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 473.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 474.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 475.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 476.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 477.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 478.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 479.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 480.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 481.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 482.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 483.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 484.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 485.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 486.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 487.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 488.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 489.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 490.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 491.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 492.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 493.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 494.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 495.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 496.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 497.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 498.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 499.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 500.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 501.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 502.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 503.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 504.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 505.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 506.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 507.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 508.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 509.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 510.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 511.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 512.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 513.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 514.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 515.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 516.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 517.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 518.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 519.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 520.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 521.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 522.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 523.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 524.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 525.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 526.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 527.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 528.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 529.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 530.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 531.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 532.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 533.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 534.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 535.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 536.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 537.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 538.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 539.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 540.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 541.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 542.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 543.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 544.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 545.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 546.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 547.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 548.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 549.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 550.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 551.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 552.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 553.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 554.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 555.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 556.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 557.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 558.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 559.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 560.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 561.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 562.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 563.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 564.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 565.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 566.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 567.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 568.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 569.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 570.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 571.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 572.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 573.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 574.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 575.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 576.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 577.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 578.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 579.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 580.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 581.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 582.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 583.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 584.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 585.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 586.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 587.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 588.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 589.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 590.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 591.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 592.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 593.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 594.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 595.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 596.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 597.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 598.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 599.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 600.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 601.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 602.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 603.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 604.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 605.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 606.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 607.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 608.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 609.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 610.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 611.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 612.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 613.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 614.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 615.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 616.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 617.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 618.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 619.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 620.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 621.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 622.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 623.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 624.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 625.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 626.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 627.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 628.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 629.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 630.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 631.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 632.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 633.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 634.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 635.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 636.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 637.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 638.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 639.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 640.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 641.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 642.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 643.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 644.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 645.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 646.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 647.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 648.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 649.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 650.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 651.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 652.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 653.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 654.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 655.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 656.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 657.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 658.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 659.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 660.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 661.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 662.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 663.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 664.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 665.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 666.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 667.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 668.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 669.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 670.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 671.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 672.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 673.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 674.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 675.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 676.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 677.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 678.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 679.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 680.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 681.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 682.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 683.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 684.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 685.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 686.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 687.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 688.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 689.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 690.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 691.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 692.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 693.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 694.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 695.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 696.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 697.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 698.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 699.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 700.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 701.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 702.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 703.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 704.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 705.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 706.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 707.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 708.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 709.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 710.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 711.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 712.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 713.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 714.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 715.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 716.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 717.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 718.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 719.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 720.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 721.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 722.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 723.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 724.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 725.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 726.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 727.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 728.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 729.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 730.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 731.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 732.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 733.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 734.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 735.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 736.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 737.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 738.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 739.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 740.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 741.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 742.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 743.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 744.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 745.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 746.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 747.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 748.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 749.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 750.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 751.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 752.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 753.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 754.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 755.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 756.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 757.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 758.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 759.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 760.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 761.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 762.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 763.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 764.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 765.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 766.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 767.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 768.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 769.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 770.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 771.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 772.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 773.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 774.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 775.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 776.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 777.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 778.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 779.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 780.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 781.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 782.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 783.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 784.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 785.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 786.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 787.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 788.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 789.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 790.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 791.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 792.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 793.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 794.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 795.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 796.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 797.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 798.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 799.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 800.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 801.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 802.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 803.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 804.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 805.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 806.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 807.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 808.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 809.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 810.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 811.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 812.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 813.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 814.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 815.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 816.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 817.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 818.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 819.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 820.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 821.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 822.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 823.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 824.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 825.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 826.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 827.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 828.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 829.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 830.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 831.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 832.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 833.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 834.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 835.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 836.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 837.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 838.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 839.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 840.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 841.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 842.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 843.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 844.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 845.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 846.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 847.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 848.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 849.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 850.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 851.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 852.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 853.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 854.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 855.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 856.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 857.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 858.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 859.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 860.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 861.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 862.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 863.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 864.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 865.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 866.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 867.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 868.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 869.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 870.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 871.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 872.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 873.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 874.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 875.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 876.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 877.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 878.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 879.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 880.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 881.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 882.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 883.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 884.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 885.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 886.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 887.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 888.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 889.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 890.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 891.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 892.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 893.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 894.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 895.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 896.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 897.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 898.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 899.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 900.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 901.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 902.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 903.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 904.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 905.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# Image 906.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\train_negative\
# ...
# Image 63.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 64.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 65.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 66.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 67.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 68.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 69.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 70.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 71.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 72.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 73.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 74.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 75.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 76.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 77.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 78.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 79.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 80.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 81.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 82.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 83.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 84.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 85.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 86.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 87.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 88.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 89.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 90.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 91.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 92.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 93.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 94.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 95.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 96.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 97.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 98.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 99.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 100.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 101.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 102.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 103.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 104.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 105.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 106.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 107.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 108.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 109.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 110.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 111.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 112.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 113.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 114.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 115.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 116.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 117.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 118.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 119.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 120.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 121.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 122.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 123.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 124.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 125.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 126.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 127.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 128.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 129.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 130.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 131.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 132.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 133.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 134.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 135.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 136.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 137.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 138.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 139.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 140.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 141.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 142.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 143.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 144.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 145.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 146.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 147.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 148.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 149.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 150.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 151.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 152.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 153.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 154.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 155.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 156.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 157.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 158.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 159.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 160.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 161.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 162.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 163.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 164.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 165.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 166.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 167.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 168.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 169.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 170.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 171.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 172.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 173.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 174.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 175.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 176.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 177.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 178.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 179.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 180.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 181.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 182.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 183.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 184.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 185.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 186.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 187.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 188.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 189.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 190.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 191.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 192.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 193.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 194.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 195.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 196.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 197.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 198.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 199.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 200.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 201.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 202.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 203.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 204.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 205.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 206.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 207.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 208.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 209.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 210.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 211.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 212.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 213.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 214.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 215.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 216.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 217.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 218.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 219.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 220.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 221.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 222.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 223.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 224.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 225.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 226.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 227.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 228.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Image 229.png saved in G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\\valid_positive\
# Directory created:  G:\\My Drive\\SKOLA\\Bachelor_work\\XR_ELBOW_roi_clahe\p
# All images were processed.
